# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.00, high=90.00, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.00, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the requests library
import requests

# Import the API Key
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | esperance
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | koumac
# Processing Record 8 of Set 1 | kununurra
# Processing Record 9 of Set 1 | yulara
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 1 | vung tau
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | aksu
# Processing Record 19 of Set 1 | hobyo
# Processing Record 20 of Set 1 | chuy
# Processing Record 21 of Set 1 | ruteng
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | of
# City not found. Skipping...
# Processing Record 26 of Set 1 | santa comba
# Processing Record 27 of Set 1 | kavieng
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | nakusp
# Processing Record 31 of Set 1 | port hardy
# Processing Record 32 of Set 1 | beringovskiy
# Processing Record 33 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 1 | hambantota
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | kruisfontein
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | peniche
# Processing Record 39 of Set 1 | saldanha
# Processing Record 40 of Set 1 | port elizabeth
# Processing Record 41 of Set 1 | muisne
# Processing Record 42 of Set 1 | nizhneangarsk
# Processing Record 43 of Set 1 | khomeyn
# Processing Record 44 of Set 1 | sao fidelis
# Processing Record 45 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 1 | provideniya
# Processing Record 48 of Set 1 | boca del monte
# Processing Record 49 of Set 1 | oyama
# Processing Record 50 of Set 1 | tessalit
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | prieska
# Processing Record 3 of Set 2 | chokurdakh
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | tilichiki
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | lahijan
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | thompson
# Processing Record 10 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 2 | mnichovice
# Processing Record 12 of Set 2 | lodja
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | cherskiy
# Processing Record 17 of Set 2 | roma
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | sakaiminato
# Processing Record 20 of Set 2 | talnakh
# Processing Record 21 of Set 2 | labuhan
# Processing Record 22 of Set 2 | iqaluit
# Processing Record 23 of Set 2 | mahebourg
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | tianpeng
# Processing Record 26 of Set 2 | kos
# Processing Record 27 of Set 2 | yarada
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | itambacuri
# Processing Record 31 of Set 2 | ketchikan
# Processing Record 32 of Set 2 | pisco
# Processing Record 33 of Set 2 | prince rupert
# Processing Record 34 of Set 2 | vaini
# Processing Record 35 of Set 2 | dongsheng
# Processing Record 36 of Set 2 | lahat
# Processing Record 37 of Set 2 | hami
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | bethel
# Processing Record 40 of Set 2 | nanortalik
# Processing Record 41 of Set 2 | fairbanks
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | kalianget
# Processing Record 44 of Set 2 | port hawkesbury
# Processing Record 45 of Set 2 | cockburn town
# Processing Record 46 of Set 2 | torbay
# Processing Record 47 of Set 2 | santa flavia
# Processing Record 48 of Set 2 | alexandria
# Processing Record 49 of Set 2 | lavrentiya
# Processing Record 50 of Set 2 | upernavik
# Processing Record 1 of Set 3 | miri
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 3 | taoudenni
# Processing Record 6 of Set 3 | saint anthony
# Processing Record 7 of Set 3 | geraldton
# Processing Record 8 of Set 3 | awjilah
# Processing Record 9 of Set 3 | keti bandar
# Processing Record 10 of Set 3 | kodiak
# Processing Record 11 of Set 3 | te anau
# Processing Record 12 of Set 3 | richards bay
# Processing Record 13 of Set 3 | hualmay
# Processing Record 14 of Set 3 | yaan
# Processing Record 15 of Set 3 | tura
# Processing Record 16 of Set 3 | lander
# Processing Record 17 of Set 3 | sunam
# Processing Record 18 of Set 3 | kupang
# Processing Record 19 of Set 3 | rapid valley
# Processing Record 20 of Set 3 | belmonte
# Processing Record 21 of Set 3 | bengkulu
# Processing Record 22 of Set 3 | padang
# Processing Record 23 of Set 3 | narsaq
# Processing Record 24 of Set 3 | port alfred
# Processing Record 25 of Set 3 | goedereede
# Processing Record 26 of Set 3 | college
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | leningradskiy
# Processing Record 29 of Set 3 | tucuma
# Processing Record 30 of Set 3 | sao filipe
# Processing Record 31 of Set 3 | zambezi
# Processing Record 32 of Set 3 | santa barbara
# Processing Record 33 of Set 3 | great yarmouth
# Processing Record 34 of Set 3 | severo-kurilsk
# Processing Record 35 of Set 3 | clyde river
# Processing Record 36 of Set 3 | puerto ayora
# Processing Record 37 of Set 3 | nikolskoye
# Processing Record 38 of Set 3 | glendive
# Processing Record 39 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 3 | banyo
# Processing Record 41 of Set 3 | east london
# Processing Record 42 of Set 3 | clearwater
# Processing Record 43 of Set 3 | cayenne
# Processing Record 44 of Set 3 | laguna
# Processing Record 45 of Set 3 | khuzdar
# Processing Record 46 of Set 3 | port lincoln
# Processing Record 47 of Set 3 | saskylakh
# Processing Record 48 of Set 3 | komsomolskiy
# Processing Record 49 of Set 3 | aksarka
# Processing Record 50 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 1 of Set 4 | cidreira
# Processing Record 2 of Set 4 | korla
# Processing Record 3 of Set 4 | suntar
# Processing Record 4 of Set 4 | bredasdorp
# Processing Record 5 of Set 4 | namwala
# Processing Record 6 of Set 4 | russell
# Processing Record 7 of Set 4 | poum
# Processing Record 8 of Set 4 | gediz
# Processing Record 9 of Set 4 | butaritari
# Processing Record 10 of Set 4 | ahipara
# Processing Record 11 of Set 4 | chapayeve
# Processing Record 12 of Set 4 | tanete
# Processing Record 13 of Set 4 | luwuk
# Processing Record 14 of Set 4 | gizo
# Processing Record 15 of Set 4 | norman wells
# Processing Record 16 of Set 4 | kondoa
# Processing Record 17 of Set 4 | codrington
# Processing Record 18 of Set 4 | nhulunbuy
# Processing Record 19 of Set 4 | harindanga
# Processing Record 20 of Set 4 | hat yai
# Processing Record 21 of Set 4 | olafsvik
# Processing Record 22 of Set 4 | arawa
# Processing Record 23 of Set 4 | bowen
# Processing Record 24 of Set 4 | souillac
# Processing Record 25 of Set 4 | launceston
# Processing Record 26 of Set 4 | ostrovnoy
# Processing Record 27 of Set 4 | margate
# Processing Record 28 of Set 4 | guanhaes
# Processing Record 29 of Set 4 | ponta do sol
# Processing Record 30 of Set 4 | sri aman
# Processing Record 31 of Set 4 | salalah
# Processing Record 32 of Set 4 | lorengau
# Processing Record 33 of Set 4 | ferme-neuve
# Processing Record 34 of Set 4 | bambous virieux
# Processing Record 35 of Set 4 | troy
# Processing Record 36 of Set 4 | gazojak
# Processing Record 37 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 4 | namibe
# Processing Record 40 of Set 4 | kahului
# Processing Record 41 of Set 4 | caceres
# Processing Record 42 of Set 4 | aklavik
# Processing Record 43 of Set 4 | saint-donat-de-montcalm
# Processing Record 44 of Set 4 | tyup
# Processing Record 45 of Set 4 | chato
# Processing Record 46 of Set 4 | moron
# Processing Record 47 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 4 | vila franca do campo
# Processing Record 49 of Set 4 | touros
# Processing Record 50 of Set 4 | tecoanapa
# Processing Record 1 of Set 5 | atbasar
# Processing Record 2 of Set 5 | chatellerault
# Processing Record 3 of Set 5 | sorland
# Processing Record 4 of Set 5 | mananjary
# Processing Record 5 of Set 5 | imbituba
# Processing Record 6 of Set 5 | bambanglipuro
# Processing Record 7 of Set 5 | houma
# Processing Record 8 of Set 5 | marzuq
# Processing Record 9 of Set 5 | kikwit
# Processing Record 10 of Set 5 | tevaitoa
# Processing Record 11 of Set 5 | yuncheng
# Processing Record 12 of Set 5 | kuryk
# Processing Record 13 of Set 5 | dunedin
# Processing Record 14 of Set 5 | zhezkazgan
# Processing Record 15 of Set 5 | mogadishu
# Processing Record 16 of Set 5 | khandbari
# Processing Record 17 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 5 | waitati
# Processing Record 19 of Set 5 | calbuco
# Processing Record 20 of Set 5 | bandarbeyla
# Processing Record 21 of Set 5 | hongjiang
# Processing Record 22 of Set 5 | pacific grove
# Processing Record 23 of Set 5 | umm ruwabah
# City not found. Skipping...
# Processing Record 24 of Set 5 | kemijarvi
# Processing Record 25 of Set 5 | waipawa
# Processing Record 26 of Set 5 | havoysund
# Processing Record 27 of Set 5 | fuxin
# Processing Record 28 of Set 5 | asyut
# Processing Record 29 of Set 5 | dalvik
# Processing Record 30 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 32 of Set 5 | swan hill
# Processing Record 33 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 34 of Set 5 | rocha
# Processing Record 35 of Set 5 | wattegama
# Processing Record 36 of Set 5 | cabo san lucas
# Processing Record 37 of Set 5 | lebu
# Processing Record 38 of Set 5 | manado
# Processing Record 39 of Set 5 | dariba
# Processing Record 40 of Set 5 | tasiilaq
# Processing Record 41 of Set 5 | sebinkarahisar
# Processing Record 42 of Set 5 | broome
# Processing Record 43 of Set 5 | santa rosa
# Processing Record 44 of Set 5 | moncao
# Processing Record 45 of Set 5 | matagami
# Processing Record 46 of Set 5 | kaitangata
# Processing Record 47 of Set 5 | kutum
# Processing Record 48 of Set 5 | urengoy
# Processing Record 49 of Set 5 | khilok
# Processing Record 50 of Set 5 | yerkoy
# Processing Record 1 of Set 6 | victoria
# Processing Record 2 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 6 | dingle
# Processing Record 4 of Set 6 | ust-ilimsk
# Processing Record 5 of Set 6 | raga
# Processing Record 6 of Set 6 | nishihara
# Processing Record 7 of Set 6 | buguruslan
# Processing Record 8 of Set 6 | parras
# City not found. Skipping...
# Processing Record 9 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 10 of Set 6 | carutapera
# Processing Record 11 of Set 6 | morondava
# Processing Record 12 of Set 6 | cao bang
# Processing Record 13 of Set 6 | katsuura
# Processing Record 14 of Set 6 | sibolga
# Processing Record 15 of Set 6 | batticaloa
# Processing Record 16 of Set 6 | novobirilyussy
# Processing Record 17 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 18 of Set 6 | palana
# Processing Record 19 of Set 6 | egvekinot
# Processing Record 20 of Set 6 | orocue
# Processing Record 21 of Set 6 | kamaishi
# Processing Record 22 of Set 6 | longyearbyen
# Processing Record 23 of Set 6 | tona
# Processing Record 24 of Set 6 | buraydah
# Processing Record 25 of Set 6 | catumbela
# Processing Record 26 of Set 6 | novaya zaimka
# Processing Record 27 of Set 6 | khatanga
# Processing Record 28 of Set 6 | mingaora
# Processing Record 29 of Set 6 | adre
# Processing Record 30 of Set 6 | luderitz
# Processing Record 31 of Set 6 | tiksi
# Processing Record 32 of Set 6 | maniwaki
# Processing Record 33 of Set 6 | gibara
# Processing Record 34 of Set 6 | san patricio
# Processing Record 35 of Set 6 | boyle
# Processing Record 36 of Set 6 | novovasylivka
# Processing Record 37 of Set 6 | kattivakkam
# Processing Record 38 of Set 6 | lugovoy
# Processing Record 39 of Set 6 | xintai
# Processing Record 40 of Set 6 | baykalsk
# Processing Record 41 of Set 6 | port macquarie
# Processing Record 42 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 43 of Set 6 | miranda
# Processing Record 44 of Set 6 | okhotsk
# Processing Record 45 of Set 6 | matadi
# Processing Record 46 of Set 6 | san pedro
# Processing Record 47 of Set 6 | sorong
# Processing Record 48 of Set 6 | poya
# Processing Record 49 of Set 6 | mendahara
# City not found. Skipping...
# Processing Record 50 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 7 | mayo
# Processing Record 2 of Set 7 | tolaga bay
# Processing Record 3 of Set 7 | lazaro cardenas
# Processing Record 4 of Set 7 | srandakan
# Processing Record 5 of Set 7 | puerto gaitan
# Processing Record 6 of Set 7 | saint george
# Processing Record 7 of Set 7 | fortuna
# Processing Record 8 of Set 7 | haines junction
# Processing Record 9 of Set 7 | faya
# Processing Record 10 of Set 7 | pitimbu
# Processing Record 11 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 7 | satoraljaujhely
# Processing Record 13 of Set 7 | kyabe
# Processing Record 14 of Set 7 | bonthe
# Processing Record 15 of Set 7 | prainha
# Processing Record 16 of Set 7 | sitka
# Processing Record 17 of Set 7 | merauke
# Processing Record 18 of Set 7 | ballina
# Processing Record 19 of Set 7 | oussouye
# Processing Record 20 of Set 7 | trincomalee
# Processing Record 21 of Set 7 | nichinan
# Processing Record 22 of Set 7 | sobolevo
# Processing Record 23 of Set 7 | lompoc
# Processing Record 24 of Set 7 | eyl
# Processing Record 25 of Set 7 | palu
# Processing Record 26 of Set 7 | coihaique
# Processing Record 27 of Set 7 | palmer
# Processing Record 28 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 29 of Set 7 | bonavista
# Processing Record 30 of Set 7 | tuatapere
# Processing Record 31 of Set 7 | diphu
# Processing Record 32 of Set 7 | mabaruma
# Processing Record 33 of Set 7 | saebovik
# City not found. Skipping...
# Processing Record 34 of Set 7 | maumere
# Processing Record 35 of Set 7 | tromso
# Processing Record 36 of Set 7 | nouakchott
# Processing Record 37 of Set 7 | igrim
# Processing Record 38 of Set 7 | saint-felix-de-valois
# Processing Record 39 of Set 7 | hovd
# Processing Record 40 of Set 7 | vestmannaeyjar
# Processing Record 41 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 42 of Set 7 | divnomorskoye
# Processing Record 43 of Set 7 | puerto maldonado
# Processing Record 44 of Set 7 | tooele
# Processing Record 45 of Set 7 | pelym
# Processing Record 46 of Set 7 | rio grande
# Processing Record 47 of Set 7 | disna
# Processing Record 48 of Set 7 | lyubeshiv
# City not found. Skipping...
# Processing Record 49 of Set 7 | aljezur
# Processing Record 50 of Set 7 | kargopol
# Processing Record 1 of Set 8 | alugan
# Processing Record 2 of Set 8 | roros
# Processing Record 3 of Set 8 | doha
# Processing Record 4 of Set 8 | lagoa
# Processing Record 5 of Set 8 | fremont
# Processing Record 6 of Set 8 | dali
# Processing Record 7 of Set 8 | caravelas
# Processing Record 8 of Set 8 | burnie
# Processing Record 9 of Set 8 | jomalig
# City not found. Skipping...
# Processing Record 10 of Set 8 | vardo
# Processing Record 11 of Set 8 | quelimane
# Processing Record 12 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 8 | kajaani
# Processing Record 14 of Set 8 | rawson
# Processing Record 15 of Set 8 | tortoli
# Processing Record 16 of Set 8 | verkhoyansk
# Processing Record 17 of Set 8 | antalaha
# Processing Record 18 of Set 8 | khorramabad
# Processing Record 19 of Set 8 | sidi bu zayd
# City not found. Skipping...
# Processing Record 20 of Set 8 | ciudad bolivar
# Processing Record 21 of Set 8 | pochutla
# Processing Record 22 of Set 8 | nabire
# Processing Record 23 of Set 8 | forrest city
# Processing Record 24 of Set 8 | sakakah
# Processing Record 25 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 8 | ambilobe
# Processing Record 27 of Set 8 | moshkovo
# Processing Record 28 of Set 8 | varhaug
# Processing Record 29 of Set 8 | dabat
# Processing Record 30 of Set 8 | sinjar
# Processing Record 31 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 32 of Set 8 | esmeraldas
# Processing Record 33 of Set 8 | mehamn
# Processing Record 34 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 8 | marawi
# Processing Record 36 of Set 8 | piterka
# Processing Record 37 of Set 8 | tukrah
# Processing Record 38 of Set 8 | klaksvik
# Processing Record 39 of Set 8 | robe
# Processing Record 40 of Set 8 | gisenyi
# Processing Record 41 of Set 8 | ampanihy
# Processing Record 42 of Set 8 | hasaki
# Processing Record 43 of Set 8 | dudinka
# Processing Record 44 of Set 8 | weihe
# Processing Record 45 of Set 8 | sambava
# Processing Record 46 of Set 8 | guadalupe y calvo
# Processing Record 47 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 8 | lumphat
# Processing Record 49 of Set 8 | makakilo city
# Processing Record 50 of Set 8 | zhuanghe
# Processing Record 1 of Set 9 | ojinaga
# Processing Record 2 of Set 9 | cap-aux-meules
# Processing Record 3 of Set 9 | hamilton
# Processing Record 4 of Set 9 | talmenka
# Processing Record 5 of Set 9 | emerald
# Processing Record 6 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 7 of Set 9 | tomigusuku
# Processing Record 8 of Set 9 | nanakuli
# Processing Record 9 of Set 9 | batagay-alyta
# Processing Record 10 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 9 | thinadhoo
# Processing Record 12 of Set 9 | mandalgovi
# Processing Record 13 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 9 | kaduy
# Processing Record 15 of Set 9 | gracanica
# Processing Record 16 of Set 9 | arcata
# Processing Record 17 of Set 9 | akyab
# Processing Record 18 of Set 9 | malakal
# Processing Record 19 of Set 9 | uyuni
# Processing Record 20 of Set 9 | camiri
# Processing Record 21 of Set 9 | tacuarembo
# Processing Record 22 of Set 9 | maniitsoq
# Processing Record 23 of Set 9 | evensk
# Processing Record 24 of Set 9 | ibra
# Processing Record 25 of Set 9 | diamantino
# Processing Record 26 of Set 9 | piacabucu
# Processing Record 27 of Set 9 | kalaiya
# Processing Record 28 of Set 9 | hailar
# Processing Record 29 of Set 9 | tartagal
# Processing Record 30 of Set 9 | isangel
# Processing Record 31 of Set 9 | ossora
# Processing Record 32 of Set 9 | tiznit
# Processing Record 33 of Set 9 | omboue
# Processing Record 34 of Set 9 | beloha
# Processing Record 35 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 9 | dakar
# Processing Record 37 of Set 9 | port blair
# Processing Record 38 of Set 9 | hofn
# Processing Record 39 of Set 9 | los llanos de aridane
# Processing Record 40 of Set 9 | biasca
# Processing Record 41 of Set 9 | mithimna
# City not found. Skipping...
# Processing Record 42 of Set 9 | constitucion
# Processing Record 43 of Set 9 | coahuayana
# Processing Record 44 of Set 9 | minab
# Processing Record 45 of Set 9 | magnitka
# Processing Record 46 of Set 9 | oranjemund
# Processing Record 47 of Set 9 | teahupoo
# Processing Record 48 of Set 9 | thunder bay
# Processing Record 49 of Set 9 | tsushima
# Processing Record 50 of Set 9 | kavali
# Processing Record 1 of Set 10 | walvis bay
# Processing Record 2 of Set 10 | zhigansk
# Processing Record 3 of Set 10 | lata
# Processing Record 4 of Set 10 | luanda
# Processing Record 5 of Set 10 | shatalovo
# Processing Record 6 of Set 10 | anadyr
# Processing Record 7 of Set 10 | mucuri
# Processing Record 8 of Set 10 | san cristobal
# Processing Record 9 of Set 10 | biak
# Processing Record 10 of Set 10 | tokur
# Processing Record 11 of Set 10 | baie-saint-paul
# Processing Record 12 of Set 10 | svetlogorsk
# Processing Record 13 of Set 10 | seoul
# Processing Record 14 of Set 10 | guerrero negro
# Processing Record 15 of Set 10 | shenjiamen
# Processing Record 16 of Set 10 | ancud
# Processing Record 17 of Set 10 | inhambane
# Processing Record 18 of Set 10 | humaita
# Processing Record 19 of Set 10 | rangpur
# Processing Record 20 of Set 10 | bongaree
# Processing Record 21 of Set 10 | sandwick
# Processing Record 22 of Set 10 | myaundzha
# Processing Record 23 of Set 10 | hornepayne
# Processing Record 24 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 10 | zhangye
# Processing Record 26 of Set 10 | flinders
# Processing Record 27 of Set 10 | rabat
# Processing Record 28 of Set 10 | port arthur
# Processing Record 29 of Set 10 | ajdabiya
# Processing Record 30 of Set 10 | inta
# Processing Record 31 of Set 10 | menongue
# Processing Record 32 of Set 10 | fukue
# Processing Record 33 of Set 10 | wonthaggi
# Processing Record 34 of Set 10 | avera
# Processing Record 35 of Set 10 | saint-pierre
# Processing Record 36 of Set 10 | athabasca
# Processing Record 37 of Set 10 | kiunga
# Processing Record 38 of Set 10 | dunmore town
# Processing Record 39 of Set 10 | port moresby
# Processing Record 40 of Set 10 | taywarah
# Processing Record 41 of Set 10 | vilhena
# Processing Record 42 of Set 10 | acapulco
# Processing Record 43 of Set 10 | koslan
# Processing Record 44 of Set 10 | ranau
# Processing Record 45 of Set 10 | dasoguz
# Processing Record 46 of Set 10 | lebanon
# Processing Record 47 of Set 10 | makat
# Processing Record 48 of Set 10 | nome
# Processing Record 49 of Set 10 | bubaque
# Processing Record 50 of Set 10 | oktyabrskiy
# Processing Record 1 of Set 11 | tazovskiy
# Processing Record 2 of Set 11 | aitape
# Processing Record 3 of Set 11 | skibbereen
# Processing Record 4 of Set 11 | ventspils
# Processing Record 5 of Set 11 | ixtapa
# Processing Record 6 of Set 11 | bilibino
# Processing Record 7 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 11 | guatire
# Processing Record 9 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 11 | alofi
# Processing Record 11 of Set 11 | broken hill
# Processing Record 12 of Set 11 | jimeta
# Processing Record 13 of Set 11 | denpasar
# Processing Record 14 of Set 11 | verkhnyaya inta
# Processing Record 15 of Set 11 | panjab
# Processing Record 16 of Set 11 | maragogi
# Processing Record 17 of Set 11 | sioux lookout
# Processing Record 18 of Set 11 | mazagao
# Processing Record 19 of Set 11 | karamken
# City not found. Skipping...
# Processing Record 20 of Set 11 | ilhabela
# Processing Record 21 of Set 11 | craig
# Processing Record 22 of Set 11 | isfana
# Processing Record 23 of Set 11 | hearst
# Processing Record 24 of Set 11 | muli
# Processing Record 25 of Set 11 | ellensburg
# Processing Record 26 of Set 11 | port-gentil
# Processing Record 27 of Set 11 | san rafael
# Processing Record 28 of Set 11 | lamar
# Processing Record 29 of Set 11 | coquimbo
# Processing Record 30 of Set 11 | toguchin
# Processing Record 31 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 11 | san andres
# Processing Record 33 of Set 11 | malpe
# Processing Record 34 of Set 11 | indianola
# Processing Record 35 of Set 11 | pitkyaranta
# Processing Record 36 of Set 11 | ilebo
# Processing Record 37 of Set 11 | kuching
# Processing Record 38 of Set 11 | tena
# Processing Record 39 of Set 11 | tezu
# Processing Record 40 of Set 11 | berdigestyakh
# Processing Record 41 of Set 11 | kalachinsk
# Processing Record 42 of Set 11 | srednekolymsk
# Processing Record 43 of Set 11 | the valley
# Processing Record 44 of Set 11 | muros
# Processing Record 45 of Set 11 | oga
# Processing Record 46 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 47 of Set 11 | oskaloosa
# Processing Record 48 of Set 11 | san juan
# Processing Record 49 of Set 11 | agadir
# Processing Record 50 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 1 of Set 12 | mponela
# Processing Record 2 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 12 | cairns
# Processing Record 4 of Set 12 | brae
# Processing Record 5 of Set 12 | araouane
# Processing Record 6 of Set 12 | saint-augustin
# Processing Record 7 of Set 12 | lang suan
# Processing Record 8 of Set 12 | junction city
# Processing Record 9 of Set 12 | seydi
# Processing Record 10 of Set 12 | hirara
# Processing Record 11 of Set 12 | praia da vitoria
# Processing Record 12 of Set 12 | sauteurs
# Processing Record 13 of Set 12 | santa ana
# Processing Record 14 of Set 12 | arlit
# Processing Record 15 of Set 12 | nyurba
# Processing Record 16 of Set 12 | tautira
# Processing Record 17 of Set 12 | pevek
# Processing Record 18 of Set 12 | riyadh
# Processing Record 19 of Set 12 | elyria
# Processing Record 20 of Set 12 | krasnovishersk
# Processing Record 21 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 22 of Set 12 | najran
# Processing Record 23 of Set 12 | ikom
# Processing Record 24 of Set 12 | alamos
# Processing Record 25 of Set 12 | pyryatyn
# Processing Record 26 of Set 12 | yumen
# Processing Record 27 of Set 12 | pangnirtung
# Processing Record 28 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 12 | karaton
# Processing Record 30 of Set 12 | marondera
# Processing Record 31 of Set 12 | bucerias
# Processing Record 32 of Set 12 | sao joao da barra
# Processing Record 33 of Set 12 | rafraf
# Processing Record 34 of Set 12 | datagon
# Processing Record 35 of Set 12 | necochea
# Processing Record 36 of Set 12 | daoukro
# Processing Record 37 of Set 12 | varkkallai
# Processing Record 38 of Set 12 | jardim
# Processing Record 39 of Set 12 | dauphin
# Processing Record 40 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 41 of Set 12 | udachnyy
# Processing Record 42 of Set 12 | bossembele
# City not found. Skipping...
# Processing Record 43 of Set 12 | okahandja
# Processing Record 44 of Set 12 | moerai
# Processing Record 45 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 12 | cahors
# Processing Record 47 of Set 12 | manggar
# Processing Record 48 of Set 12 | silva jardim
# Processing Record 49 of Set 12 | conway
# Processing Record 50 of Set 12 | zaria
# Processing Record 1 of Set 13 | wahiawa
# Processing Record 2 of Set 13 | mosquera
# Processing Record 3 of Set 13 | rondonopolis
# Processing Record 4 of Set 13 | ust-maya
# Processing Record 5 of Set 13 | corum
# Processing Record 6 of Set 13 | teeli
# Processing Record 7 of Set 13 | ambon
# Processing Record 8 of Set 13 | rio tercero
# Processing Record 9 of Set 13 | rio gallegos
# Processing Record 10 of Set 13 | la seyne-sur-mer
# Processing Record 11 of Set 13 | corciano
# Processing Record 12 of Set 13 | magdagachi
# Processing Record 13 of Set 13 | port augusta
# Processing Record 14 of Set 13 | arrifes
# Processing Record 15 of Set 13 | newton
# Processing Record 16 of Set 13 | windsor
# Processing Record 17 of Set 13 | sansai
# City not found. Skipping...
# Processing Record 18 of Set 13 | namatanai
# Processing Record 19 of Set 13 | lazarev
# Processing Record 20 of Set 13 | gamba
# Processing Record 21 of Set 13 | le vauclin
# Processing Record 22 of Set 13 | muyezerskiy
# Processing Record 23 of Set 13 | kalandagan
# Processing Record 24 of Set 13 | gilgit
# Processing Record 25 of Set 13 | mabamba
# Processing Record 26 of Set 13 | ville-marie
# Processing Record 27 of Set 13 | shimoda
# Processing Record 28 of Set 13 | podgornoye
# Processing Record 29 of Set 13 | korgen
# Processing Record 30 of Set 13 | mizpe ramon
# City not found. Skipping...
# Processing Record 31 of Set 13 | havre-saint-pierre
# Processing Record 32 of Set 13 | sainte-thecle
# Processing Record 33 of Set 13 | camacha
# Processing Record 34 of Set 13 | puerto colombia
# Processing Record 35 of Set 13 | moose factory
# Processing Record 36 of Set 13 | montlucon
# Processing Record 37 of Set 13 | northam
# Processing Record 38 of Set 13 | monte alegre de minas
# Processing Record 39 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 40 of Set 13 | syracuse
# Processing Record 41 of Set 13 | plettenberg bay
# Processing Record 42 of Set 13 | maridi
# Processing Record 43 of Set 13 | virginia beach
# Processing Record 44 of Set 13 | gerede
# Processing Record 45 of Set 13 | samarai
# Processing Record 46 of Set 13 | akdepe
# Processing Record 47 of Set 13 | kaka
# Processing Record 48 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 49 of Set 13 | kalmunai
# Processing Record 50 of Set 13 | vao
# Processing Record 1 of Set 14 | mackenzie
# Processing Record 2 of Set 14 | kroya
# Processing Record 3 of Set 14 | dunkwa
# Processing Record 4 of Set 14 | bima
# Processing Record 5 of Set 14 | mnogovershinnyy
# Processing Record 6 of Set 14 | manjakandriana
# Processing Record 7 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 14 | zhuhai
# Processing Record 9 of Set 14 | yenotayevka
# Processing Record 10 of Set 14 | nacala
# Processing Record 11 of Set 14 | whyalla
# Processing Record 12 of Set 14 | hurricane
# Processing Record 13 of Set 14 | guata
# City not found. Skipping...
# Processing Record 14 of Set 14 | point pedro
# Processing Record 15 of Set 14 | soyo
# Processing Record 16 of Set 14 | kingsport
# Processing Record 17 of Set 14 | revda
# Processing Record 18 of Set 14 | vila
# Processing Record 19 of Set 14 | litoral del san juan
# City not found. Skipping...
# Processing Record 20 of Set 14 | las vegas
# Processing Record 21 of Set 14 | honningsvag
# Processing Record 22 of Set 14 | inyonga
# Processing Record 23 of Set 14 | ulkan
# Processing Record 24 of Set 14 | sabang
# Processing Record 25 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 14 | santa isabel do rio negro
# Processing Record 27 of Set 14 | russkoye
# Processing Record 28 of Set 14 | shu
# Processing Record 29 of Set 14 | tateyama
# Processing Record 30 of Set 14 | micheweni
# Processing Record 31 of Set 14 | iquique
# Processing Record 32 of Set 14 | dubuque
# Processing Record 33 of Set 14 | yibin
# Processing Record 34 of Set 14 | barao de melgaco
# Processing Record 35 of Set 14 | mahanje
# Processing Record 36 of Set 14 | chernyshevskiy
# Processing Record 37 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 14 | comodoro rivadavia
# Processing Record 39 of Set 14 | grand gaube
# Processing Record 40 of Set 14 | manokwari
# Processing Record 41 of Set 14 | north platte
# Processing Record 42 of Set 14 | maceio
# Processing Record 43 of Set 14 | erenhot
# Processing Record 44 of Set 14 | deniliquin
# Processing Record 45 of Set 14 | bloemfontein
# Processing Record 46 of Set 14 | san ramon
# Processing Record 47 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 14 | rawah
# Processing Record 49 of Set 14 | hudiksvall
# Processing Record 50 of Set 14 | karratha
# Processing Record 1 of Set 15 | unity
# Processing Record 2 of Set 15 | yigou
# Processing Record 3 of Set 15 | healdsburg
# Processing Record 4 of Set 15 | talara
# Processing Record 5 of Set 15 | amuntai
# Processing Record 6 of Set 15 | ilulissat
# Processing Record 7 of Set 15 | atherton
# Processing Record 8 of Set 15 | sesheke
# Processing Record 9 of Set 15 | arequipa
# Processing Record 10 of Set 15 | taoyuan
# Processing Record 11 of Set 15 | lysva
# Processing Record 12 of Set 15 | giyani
# Processing Record 13 of Set 15 | tahta
# Processing Record 14 of Set 15 | villarrica
# Processing Record 15 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 15 | san jeronimo
# Processing Record 17 of Set 15 | roald
# Processing Record 18 of Set 15 | cuiluan
# Processing Record 19 of Set 15 | yarim
# Processing Record 20 of Set 15 | burica
# City not found. Skipping...
# Processing Record 21 of Set 15 | maltahohe
# Processing Record 22 of Set 15 | kaohsiung
# Processing Record 23 of Set 15 | vicuna
# Processing Record 24 of Set 15 | la ronge
# Processing Record 25 of Set 15 | ko samui
# Processing Record 26 of Set 15 | baghdad
# Processing Record 27 of Set 15 | ravenna
# Processing Record 28 of Set 15 | latung
# Processing Record 29 of Set 15 | eydhafushi
# Processing Record 30 of Set 15 | aksay
# Processing Record 31 of Set 15 | hukuntsi
# Processing Record 32 of Set 15 | krasnoselkup
# Processing Record 33 of Set 15 | kuroiso
# Processing Record 34 of Set 15 | half moon bay
# Processing Record 35 of Set 15 | saint-joseph
# Processing Record 36 of Set 15 | paamiut
# Processing Record 37 of Set 15 | palmares do sul
# Processing Record 38 of Set 15 | pervomayskiy
# Processing Record 39 of Set 15 | berlevag
# Processing Record 40 of Set 15 | havelock
# Processing Record 41 of Set 15 | kegalla
# City not found. Skipping...
# Processing Record 42 of Set 15 | acajutla
# Processing Record 43 of Set 15 | victor harbor
# Processing Record 44 of Set 15 | pundaguitan
# Processing Record 45 of Set 15 | jalna
# Processing Record 46 of Set 15 | aswan
# Processing Record 47 of Set 15 | pryazha
# Processing Record 48 of Set 15 | mariel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

#Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Tuktoyaktuk      CA  69.4541 -133.0374    -13.47        89          98
# 1       Faanui      PF -16.4833 -151.7500     80.69        74          49
# 2       Barrow      US  71.2906 -156.7887    -14.80        75           1
# 3    Esperance      AU -33.8667  121.9000     75.20        44           0
# 4      Mataura      NZ -46.1927  168.8643     64.99        93         100
# 5       Koumac      NC -20.5667  164.2833     81.84        80          87
# 6    Kununurra      AU -15.7667  128.7333     96.80        47          70
# 7       Yulara      AU -25.2406  130.9889     87.80        12           1
# 8      Qaanaaq      GL  77.4840  -69.3632     -6.61        85         100
# 9       Castro      BR -24.7911  -50.0119     66.25        94          47
#
#    Wind Speed Current Description
# 0        5.99     overcast clouds
# 1       12.86    scattered clouds
# 2        8.05           clear sky
# 3       24.16           clear sky
# 4        1.99     overcast clouds
# 5        4.29     overcast clouds
# 6        8.05       broken clouds
# 7       14.99           clear sky
# 8        0.94     overcast clouds
# 9        6.55    scattered clouds

# %%
#Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"

#Export the city data into a csv
city_data_df.to_csv(output_data_file, index_label = "City_ID")
